# %%
import pandas as pd
from sqlalchemy import create_engine, text

def load_data( df_raw ):
    
    # criar a lista n_cols
    n_cols = ['propertyCode',
    'thumbnail',
    'externalReference',
    'numPhotos',
    'price',
    'propertyType',
    'operation',
    'size',
    'exterior',
    'rooms',
    'bathrooms',
    'address','province',
    'municipality',
    'district',
    'country','latitude',
    'longitude',
    'showAddress',
    'url',
    'distance',
    'description',
    'hasVideo',
    'status',
    'newDevelopment',
    'priceByArea',
    'detailedType',
    'suggestedTexts',
    'hasPlan',
    'has3DTour',
    'has360',
    'hasStaging',
    'topNewDevelopment',
    'superTopHighlight',
    'floor',
    'hasLift',
    'parkingSpace',
    'neighborhood',
    'labels',
    'pagina',
    'datetime_scrapy',
    'newDevelopmentFinished']

    if len( df_raw.columns ) == len( n_cols ):

        # crio a conexao com o banco de dados
        engine = create_engine('sqlite:///bd_houses_rent_api.sqlite', echo = False)

        # ordena as colunas 
        df_raw = df_raw[['propertyCode',
                        'thumbnail',
                        'externalReference',
                        'numPhotos',
                        'price',
                        'propertyType',
                        'operation',
                        'size',
                        'exterior',
                        'rooms',
                        'bathrooms',
                        'address','province',
                        'municipality',
                        'district',
                        'country','latitude',
                        'longitude',
                        'showAddress',
                        'url',
                        'distance',
                        'description',
                        'hasVideo',
                        'status',
                        'newDevelopment',
                        'priceByArea',
                        'detailedType',
                        'suggestedTexts',
                        'hasPlan',
                        'has3DTour',
                        'has360',
                        'hasStaging',
                        'topNewDevelopment',
                        'superTopHighlight',
                        'floor',
                        'hasLift',
                        'parkingSpace',
                        'neighborhood',
                        'labels',
                        'pagina',
                        'datetime_scrapy',
                        'newDevelopmentFinished']]

        # carrego os dados no db
        df_raw.to_sql( 'houses', con = engine , if_exists = 'append' ,index = False )

        # exibe mensagem
        print( 'dados carregados com sucesso' )
        
        # fecha a conexao com o bd
        
        engine.dispose()

    else:

        print( 'numero de colunas divergentes' )
        
    return None

# %%
# importo dados

df_teste = pd.read_excel( r'data/extracao_3_3_2023.xlsx' )

load_data( df_teste )
# Out:
# dados carregados com sucesso

# %%
# crio a conexao com o banco de dados
engine = create_engine('sqlite:///bd_houses_rent_api.sqlite', echo = False)
## Query consulta
query_consulta = text('''

SELECT * from houses

''')

conn = engine.connect()

query = pd.read_sql( query_consulta , con = conn )

conn.close()

query
# Out:
#       propertyCode                                          thumbnail  \
# 0       32370259.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 1       30481990.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 2       32372804.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 3       32372800.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 4       30438281.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# ...            ...                                                ...
# 5129    32431304.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 5130    32411660.0  https://img3.idealista.pt/blur/WEB_LISTING/0/i...
# 5131    31767846.0                                               None
# 5132    32475911.0                                               None
# 5133    32225335.0                                               None
#
#      externalReference  numPhotos   price propertyType operation    size  \
# 0        124071008-187       25.0  2400.0         flat      rent   124.0
# 1                   PL        9.0   900.0         flat      rent    60.0
# 2              APA_311       41.0  2100.0         flat      rent   110.0
# 3             HAB_4283       33.0  5000.0       chalet      rent  1000.0
# 4                 5675       15.0  1400.0         flat      rent    65.0
# ...                ...        ...     ...          ...       ...     ...
# 5129             00267       11.0   850.0         flat      rent    50.0
# 5130      126011001-29        7.0  1200.0         flat      rent   113.0
# 5131       110/22 - JL        0.0  8500.0       chalet      rent   215.0
# 5132              None        0.0   580.0         flat      rent    60.0
# 5133              None        0.0   650.0         flat      rent    60.0
#
#       exterior  rooms  ...  topNewDevelopment superTopHighlight floor hasLift  \
# 0          0.0    2.0  ...                0.0               0.0  None     NaN
# 1          0.0    1.0  ...                0.0               0.0    bj     0.0
# 2          0.0    2.0  ...                0.0               0.0     3     1.0
# 3          0.0    4.0  ...                0.0               0.0  None     NaN
# 4          0.0    1.0  ...                0.0               0.0    bj     0.0
# ...        ...    ...  ...                ...               ...   ...     ...
# 5129       0.0    1.0  ...                0.0               0.0     8     1.0
# 5130       0.0    3.0  ...                0.0               0.0  None     0.0
# 5131       0.0    4.0  ...                0.0               0.0  None     NaN
# 5132       0.0    1.0  ...                0.0               0.0    bj     0.0
# 5133       0.0    1.0  ...                0.0               0.0     1     0.0
#
#                                            parkingSpace  \
# 0                                                  None
# 1     {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 2     {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 5129                                               None
# 5130                                               None
# 5131                                               None
# 5132                                               None
# 5133                                               None
#
#                 neighborhood                                       labels  \
# 0                       None                                         None
# 1                       None                                         None
# 2                  Estefânia                                         None
# 3     Bairro Santana - Cobre  [{'name': 'luxuryType', 'text': 'De luxo'}]
# 4                       None                                         None
# ...                      ...                                          ...
# 5129                    None                                         None
# 5130                    None                                         None
# 5131       Centro de Cascais  [{'name': 'luxuryType', 'text': 'De luxo'}]
# 5132                    None                                         None
# 5133                    None                                         None
#
#       pagina             datetime_scrapy newDevelopmentFinished
# 0        1.0  2023-01-07 19:41:09.000000                    NaN
# 1        1.0  2023-01-07 19:41:09.000000                    NaN
# 2        1.0  2023-01-07 19:41:09.000000                    NaN
# 3        1.0  2023-01-07 19:41:09.000000                    NaN
# 4        1.0  2023-01-07 19:41:09.000000                    NaN
# ...      ...                         ...                    ...
# 5129    37.0         2023-03-03 21:04:44                    NaN
# 5130    37.0         2023-03-03 21:04:44                    NaN
# 5131    37.0         2023-03-03 21:04:44                    NaN
# 5132    37.0         2023-03-03 21:04:44                    NaN
# 5133    37.0         2023-03-03 21:04:44                    NaN
#
# [5134 rows x 42 columns]
